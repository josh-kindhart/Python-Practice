# %%
import numpy as np
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %%
map = folium.Map(location=[37.548061-0.000125,-97.248016], tiles='OpenStreetMap', zoom_start=5, width='100%', height='70%')

# %%
df = pd.DataFrame([['Josh','Austin, Texas', 30.395450,-97.649570],
                   ['Vera', 'Cedar Park, Texas',30.509356202953924, -97.84807968855222],
                   ['Corey','Denver, Colorado', 39.54940910804747, -104.87271095352052],
                   ['Bill', 'Dripping Springs, Texas', 30.171960-0.000050, -97.995670],
                   ['Michelle', 'Dripping Springs, Texas', 30.171960-0.000125, -97.995670],
                   ['Ashlee','Derby, Kansas', 37.548061-0.000125,-97.248016],
                   ['Maverick','Derby, Kansas', 37.548061,-97.248016],
                   ['Vernon', 'Canton, Georgia',34.283930,-84.507330],
                   ['Linda', 'Canton, Georgia', 34.283930-0.000125,-84.507330]], 
                   columns=['name','city_name', 'Lat','Lon'])

# %%
for i in range(0, len(df)):
    map.add_child(
    folium.Marker(location=(df.iloc[i]['Lat'], df.iloc[i]['Lon']),
                  popup='{}\n{}'.format(df.iloc[i]['name'], df.iloc[i]['city_name'])))

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00e4641a19bda8f9823d8afe1ea133bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 70.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00e4641a19bda8f9823d8afe1ea133bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00e4641a19bda8f9823d8afe1ea133bf = L.map(
#                 &quot;map_00e4641a19bda8f9823d8afe1ea133bf&quot;,
#                 {
#                     center: [37.547936, -97.248016],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee3fe545b435cbbaf361e9c5a397954e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00e4641a19bda8f9823d8afe1ea133bf);
#
#
#             var marker_a4d1073f308148676cb5a688de61e4f4 = L.marker(
#                 [30.39545, -97.64957],
#                 {}
#             ).addTo(map_00e4641a19bda8f9823d8afe1ea133bf);
#
#
#         var popup_cc784f84e89e7a259abc194a49fe6a76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_722290c10be23ffdbb85f1d2d550a404 = $(`&lt;div id=&quot;html_722290c10be23ffdbb85f1d2d550a404&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Josh Austin, Texas&lt;/div&gt;`)[0];
#                 popup_cc784f84e89e7a259abc194a49fe6a76.setContent(html_722290c10be23ffdbb85f1d2d550a404);
#
#
#
#         marker_a4d1073f308148676cb5a688de61e4f4.bindPopup(popup_cc784f84e89e7a259abc194a49fe6a76)
#         ;
#
#
#
#
#             var marker_24f145cc8e406bf51c91ba7fed8fecb7 = L.marker(
#                 [30.509356202953924, -97.84807968855222],
#                 {}
#             ).addTo(map_00e4641a19bda8f9823d8afe1ea133bf);
#
#
#         var popup_465e10c7f3eb6311c2366427e3afb803 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8099ef278892cff7e68333b35030716f = $(`&lt;div id=&quot;html_8099ef278892cff7e68333b35030716f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vera Cedar Park, Texas&lt;/div&gt;`)[0];
#                 popup_465e10c7f3eb6311c2366427e3afb803.setContent(html_8099ef278892cff7e68333b35030716f);
#
#
#
#         marker_24f145cc8e406bf51c91ba7fed8fecb7.bindPopup(popup_465e10c7f3eb6311c2366427e3afb803)
#         ;
#
#
#
#
#             var marker_3a56b8a53598c6769c7254e5863479e6 = L.marker(
#                 [39.54940910804747, -104.87271095352052],
#                 {}
#             ).addTo(map_00e4641a19bda8f9823d8afe1ea133bf);
#
#
#         var popup_8f7a8a8f313a625ba42c929b770b69a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_60e452e1d9a2cea13c9fefcd89337297 = $(`&lt;div id=&quot;html_60e452e1d9a2cea13c9fefcd89337297&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Corey Denver, Colorado&lt;/div&gt;`)[0];
#                 popup_8f7a8a8f313a625ba42c929b770b69a6.setContent(html_60e452e1d9a2cea13c9fefcd89337297);
#
#
#
#         marker_3a56b8a53598c6769c7254e5863479e6.bindPopup(popup_8f7a8a8f313a625ba42c929b770b69a6)
#         ;
#
#
#
#
#             var marker_e587d472e62f0fe7a8c3003ae0cf8bd3 = L.marker(
#                 [30.171909999999997, -97.99567],
#                 {}
#             ).addTo(map_00e4641a19bda8f9823d8afe1ea133bf);
#
#
#         var popup_bf492caa50b0165c2db7b2081cd6519d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_baf4218639e3a10907a7cbeab3e0d1ad = $(`&lt;div id=&quot;html_baf4218639e3a10907a7cbeab3e0d1ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bill Dripping Springs, Texas&lt;/div&gt;`)[0];
#                 popup_bf492caa50b0165c2db7b2081cd6519d.setContent(html_baf4218639e3a10907a7cbeab3e0d1ad);
#
#
#
#         marker_e587d472e62f0fe7a8c3003ae0cf8bd3.bindPopup(popup_bf492caa50b0165c2db7b2081cd6519d)
#         ;
#
#
#
#
#             var marker_448539d59daa0fef61131659b02ad5ae = L.marker(
#                 [30.171834999999998, -97.99567],
#                 {}
#             ).addTo(map_00e4641a19bda8f9823d8afe1ea133bf);
#
#
#         var popup_bf25171331e6e34e980b1d1272334aca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54428a1fde645de40e2145bfa3c0f3c5 = $(`&lt;div id=&quot;html_54428a1fde645de40e2145bfa3c0f3c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Michelle Dripping Springs, Texas&lt;/div&gt;`)[0];
#                 popup_bf25171331e6e34e980b1d1272334aca.setContent(html_54428a1fde645de40e2145bfa3c0f3c5);
#
#
#
#         marker_448539d59daa0fef61131659b02ad5ae.bindPopup(popup_bf25171331e6e34e980b1d1272334aca)
#         ;
#
#
#
#
#             var
